# %%
# %run create_ucitojs.py
# Out:
# /nct11af/paws/devDesc.json open error
# /nct11af/paws/deviceOwner.json open error
# /nct11af/paws/antenna.json open error
# /nct11af/paws/nct11afurl.json open error
# nct11afurl.json open error

# %%
# %run nct11af_send.py

# %%
import datetime
datetime.datetime.now().strftime("%c")

# %%
ret_data = None
try:            
    ret_data = open("/test/nct11afurl.json").read().decode("utf-8")
except IOError, e:
    print("err: {}".format(e))
    try:
        ret_data = open("/nct11af/paws/nct11afurl.json").read().decode("utf-8")
    except IOError, e:
        print("err: {}".format(e))
